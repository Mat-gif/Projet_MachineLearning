# %%
# import sklearn as slk
# #importation
# #from google.colab import drive
# from pandas import *
# # Importation des différentes librairies, classes et fonctions utilespour le notebook

# #Sickit learn met régulièrement à jour des versions et 
# #indique des futurs warnings. 
# #ces deux lignes permettent de ne pas les afficher.
# import warnings
# warnings.filterwarnings("ignore", category=FutureWarning)


# # librairies générales
# import pandas as pd
# import re
# from tabulate import tabulate
# import time
# import numpy as np
# import pickle
# import string
# import base64
# import sys

# # librairie affichage
# import matplotlib.pyplot as plt
# import seaborn as sns

# # librairies scikit learn
# import sklearn
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.base import TransformerMixin
# from sklearn.pipeline import Pipeline
# from sklearn.model_selection import train_test_split
# from sklearn import metrics
# from sklearn.model_selection import cross_val_score
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import classification_report
# from sklearn.model_selection import KFold
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import accuracy_score


# # librairies des classifiers utilisés
# from sklearn.svm import SVC
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.ensemble import RandomForestClassifier

# # librairies NLTK
# import nltk
# from nltk.stem import WordNetLemmatizer
# from nltk.stem import PorterStemmer 
# from nltk.corpus import stopwords
# from nltk import word_tokenize 

 
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('punkt')
# stop_words = set(stopwords.words('english'))

# %%
# drive.mount('/content/drive')

# my_local_drive = "/content/drive/MyDrive/Colab Notebooks/"
# # fonctions utilities (affichage, confusion, etc.)
# sys.path.append(my_local_drive)

# # Se positionner sur le répertoire associé
# %cd $my_local_drive
# %pwd

# fonctions utilities (affichage, confusion, etc.)
from importations import *
from MyNLPUtilities import *

data_path = "E:/Semestre-2/MachineLearning/TravauxPratiques/Projet/data/HAI817_Project_data/"
dataInit_train = data_path + "HAI817_Projet_train.csv"
dfInit_train = pd.read_csv(dataInit_train)


data_path = "E:/Semestre-2/MachineLearning/TravauxPratiques/Projet/data/HAI817_Project_data/"
dataInit_test = data_path + "HAI817_Projet_test.csv"
dfInit_test = pd.read_csv(dataInit_test)

df = dfInit_train

# df = pd.concat([dfInit_test, dfInit_train], ignore_index = True)

# df.isna().mean()
# df.dropna(subset=['title'], inplace=True)

# %%
# documents = data.iloc[:, 1:].values
# documents = np.char.lower(documents.astype('U'))
documents = dfInit_train['title'].values.astype('U')

# Vectorisation des données textuelles

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)
# X
 
# Application de la NMF sur la matrice de données vectorielles
model = NMF(n_components=10, init='random', random_state=0)
W = model.fit_transform(X)
H = model.components_

# # Affichage des sujets (ou des thèmes)
for topic_idx, topic in enumerate(H):
    print("Topic %d:" % (topic_idx))
    print(" ".join([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-20 - 1:-1]]))
# Out:
# Topic 0:
# health vaccine mental people vaccines children reported deaths pfizer measles issues mothers investment services said uk trials injuries flu aaron
# Topic 1:
# covid 19 cdc virus mask nations study compare percent death masks numbers dr needed fauci report mandates dead relief recommends
# Topic 2:
# climate change incomplete flawed models science hurricane earth world intensify harvey isn rising california fresh rick did got data look
# Topic 3:
# sea rising level caught oceans adjusting impression rise create false seas scientists data average florida faster levels apocalyptic accelerating observations
# Topic 4:
# warming global say scientists recent scientific delingpole bears myth natural polar data heat begun flooding extinction coast pole driving disagreeabout
# Topic 5:
# says cancer study lung rate hitting survival late diagnosis lungs 62 cells tax smoking worse shocking treatment black finds nasa
# Topic 6:
# ...

# %%
# documents = data.iloc[:, 1:].values
# documents = np.char.lower(documents.astype('U'))
documents = dfInit_train['text'].values.astype('U')

# Vectorisation des données textuelles

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)
# X
 
# Application de la NMF sur la matrice de données vectorielles
model = NMF(n_components=10, init='random', random_state=0)
W = model.fit_transform(X)
H = model.components_

# # Affichage des sujets (ou des thèmes)
for topic_idx, topic in enumerate(H):
    print("Topic %d:" % (topic_idx))
    print(" ".join([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-20 - 1:-1]]))
# Out:
# Topic 0:
# climate co2 carbon change emissions dioxide energy pruitt warming gas global human greenhouse earth world scientists environmental planet power atmospheric
# Topic 1:
# walker wisconsin state governor said senate tax budget scott jobs million obamacare republican milwaukee democrats oregon campaign county insurance session
# Topic 2:
# warming climate global temperatures temperature heat el record earth weather nasa warm degrees years data ocean year solar surface noaa
# Topic 3:
# eu uk britain european brexit trade migrants referendum migration leave british europe cameron getty 000 said deal countries immigration union
# Topic 4:
# ballots election ballot votes voter michigan georgia fraud county absentee vote state voters poll elections voting november mail detroit cast
# Topic 5:
# trump president donald pelosi obama american house military white america election democrats pence states jan country news says people campaign
# Topic 6:
# ...
